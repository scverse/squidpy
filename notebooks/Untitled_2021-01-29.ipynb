# %%
# %load_ext autoreload
# %autoreload 2

# %%
import squidpy as sq
# Out:
# /home/michal/.miniconda3/envs/cellrank/lib/python3.8/site-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.3) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({0}) or chardet ({1}) doesn't match a supported "

# %%
adata = sq.datasets.visium_hne_adata()

# %%
sq.gr.co_occurrence(adata, cluster_key="cluster", n_splits=2)
sq.pl.co_occurrence(
    adata, cluster_key="cluster", clusters="Hippocampus", figsize=(5, 3), legend=False
)
# Out:
#   0%|          | 0/3 [00:00<?, ?/s]
# No handles with labels found to put in legend.

# %%
adata.obsm['spatial']
# Out:
# array([[8230, 7237],
#        [4170, 1611],
#        [2519, 8315],
#        ...,
#        [3276, 8435],
#        [3069, 6639],
#        [4720, 2090]])

# %%
sq.gr.co_occurrence(adata, cluster_key="cluster", n_splits=20)
sq.pl.co_occurrence(
    adata, cluster_key="cluster", clusters="Hippocampus", figsize=(5, 3), legend=False
)
# Out:
#   0%|          | 0/210 [00:00<?, ?/s]
# /opt/projects/helmholtz/squidpy/squidpy/gr/ppatterns.py:308: RuntimeWarning: invalid value encountered in true_divide
#   probs_con[c, :] = probs_conditional / probs
# /opt/projects/helmholtz/squidpy/squidpy/gr/ppatterns.py:307: RuntimeWarning: invalid value encountered in true_divide
#   probs_conditional = co_occur[c] / np.sum(co_occur[c])
# /opt/projects/helmholtz/squidpy/squidpy/gr/ppatterns.py:308: RuntimeWarning: invalid value encountered in true_divide
#   probs_con[c, :] = probs_conditional / probs
# /opt/projects/helmholtz/squidpy/squidpy/gr/ppatterns.py:307: RuntimeWarning: invalid value encountered in true_divide
#   probs_conditional = co_occur[c] / np.sum(co_occur[c])
# /opt/projects/helmholtz/squidpy/squidpy/gr/ppatterns.py:308: RuntimeWarning: divide by zero encountered in true_divide
#   probs_con[c, :] = probs_conditional / probs
# ...
